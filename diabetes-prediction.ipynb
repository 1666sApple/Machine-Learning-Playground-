# %% [markdown]
# <a href="https://www.kaggle.com/code/anannoasif/diabetes-prediction?scriptVersionId=156336228" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
db_data = pd.read_csv('/kaggle/input/diabetes-dataset/diabetes.csv')
db_data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
db_data.shape
# Out:
# (768, 9)

# %%
db_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
db_data['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
db_data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
X = db_data.drop(columns = "Outcome", axis =1)
Y = db_data["Outcome"]

# %%
scaler = StandardScaler()
scaler.fit(X)
std_data = scaler.transform(X)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.225, stratify = Y, random_state = 4)

# %%
clf = svm.SVC(kernel='linear')
clf.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_pred = clf.predict(X_train)
train_acc = accuracy_score(X_pred, Y_train)
print(train_acc)
# Out:
# 0.7899159663865546

# %%
Xt_pred = clf.predict(X_test)
traint_acc = accuracy_score(Xt_pred, Y_test)
print(traint_acc)
# Out:
# 0.7456647398843931
